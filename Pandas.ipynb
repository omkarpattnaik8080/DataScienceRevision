# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/DataScienceRevision/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/services.csv')

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#agar pehle wale row ko as header consider nahin karna
#df=pd.read_csv('/content/services.csv',header=None)

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df[['email','keywords']]
# Out:
#                     email                                           keywords
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1=pd.read_excel('/content/LUSID Excel - Setting up your market data.xlsx')

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1[['Unnamed: 6','Unnamed: 8']]
# Out:
#     Unnamed: 6                 Unnamed: 8
# 0          NaN                        NaN
# 1          NaN                        NaN
# 2          NaN                        NaN
# 3          NaN                        NaN
# 4          NaN                        NaN
# 5          NaN                        NaN
# 6          NaN                        NaN
# 7          NaN                        NaN
# 8          NaN                        NaN
# 9          NaN                        NaN
# 10         NaN                        NaN
# 11         NaN                        NaN
# 12         NaN                        NaN
# 13         NaN                        NaN
# 14         NaN                        NaN
# 15         NaN  "YYYY-MM-DDTHH:MM:SS.00Z"
# 16         NaN                        NaN
# 17         NaN   2019-04-10T 13:30:45.55Z
# 18         NaN                        NaN
# 19         NaN  2019-04-10T13:30:45+04:00
# 20         NaN                        NaN
# ...

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df2['Survived'])
# Out:
# pandas.core.series.Series

# %%
df2[['PassengerId','Survived','Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df2.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df2[['Fare','Cabin','Ticket']]
# Out:
#         Fare Cabin            Ticket
# 0     7.2500   NaN         A/5 21171
# 1    71.2833   C85          PC 17599
# 2     7.9250   NaN  STON/O2. 3101282
# 3    53.1000  C123            113803
# 4     8.0500   NaN            373450
# ..       ...   ...               ...
# 886  13.0000   NaN            211536
# 887  30.0000   B42            112053
# 888  23.4500   NaN        W./C. 6607
# 889  30.0000  C148            111369
# 890   7.7500   NaN            370376
#
# [891 rows x 3 columns]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#if i want only the objects from above
df2.dtypes[['Name','Sex','Embarked','Cabin']]
# Out:
# Name        object
# Sex         object
# Embarked    object
# Cabin       object
# dtype: object

# %%
df2.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df2.dtypes[df2.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df2.dtypes[df2.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df2[df2.dtypes[df2.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df2[df2.dtypes[df2.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df2.dtypes[df2.dtypes=='float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
#in series
df2['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df2[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
#agar mujhe 4th se lekar 10th tak data ko dekhna hai
df2[['Ticket']][4:10]
# Out:
#    Ticket
# 4  373450
# 5  330877
# 6   17463
# 7  349909
# 8  347742
# 9  237736

# %%
df2[4:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# ...

# %%
#agar hame aek naya column banana hai
df2['new_col']=0

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#if i have to make a new column jahan par mujhe passanger class aaur passanger id ko add karke dalna hai
df2['new_col2']=df2['Pclass']+df2['PassengerId']

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
#if i want to know the unique categories of the pclass
pd.Categorical(df2['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df2['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df2['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df2['Age']>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df2['Age']>18]
# Out:
# <ipython-input-54-64025b735dc3>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df2['Age']>18]
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 6    7            7         NaN                       NaN
# 8    9            9         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 15  16           16         NaN                       NaN
# 18  19           19         NaN                       NaN
# 20  21           21         NaN                       NaN
# ...

# %%
len(df2['Age']>18)
# Out:
# 891

# %%
#how much people have paid more than average
df2['Fare']>32.204208
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df2[df2['Fare']>32.204208]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2[df2['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df2['Sex']=='Female'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df2['Fare']>32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
#combination of above two conditions
df2[(df2['Fare']>32) & (df2['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#using max function
max(df2['Fare'])
# Out:
# 512.3292

# %%
#agar dataframe ke andar se kuch selected rows select karna hai
df2[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0  A/5 21171   7.2500   NaN        S        0         4
# 1      0   PC 17599  71.2833   C85        C        0         3

# %%
#agar data at even indexes nikalne hai
df2[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2[['PassengerId','Survived','Pclass']][0:2]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df2.loc[0:2,['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
df2.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0  A/5 21171   7.2500   NaN        S        0         4
# 1      0   PC 17599  71.2833   C85        C        0         3

# %%
df2.iloc[0:2,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col', 'new_col2'],
#       dtype='object')

# %%
#columns mein se ham aek data ko utha lete hain
#s=df2['Name']

# %%
#len(s)

# %%
#df2['Name'][0:10]

# %%
#how to give index from ur side
#l=['a','b','c','d','e','f','g','h','i','j']

# %%
#s[0]

# %%
#s4=pd.Series([3,4,5,6],index=[2,4,5,6])

# %%
#s4

# %%
#s.columns()

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col', 'new_col2'],
#       dtype='object')

# %%
#if we want to drop a specific column
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
df2.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#for removing a column permanently we can use inplace="True"
df2.drop('PassengerId',axis=1,inplace=True)

# %%
df2
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
#for droping the rows
df2.drop(0,axis=0)
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
#if i want the column to be the index
df2.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df2.set_index('Name',inplace=True)

# %%
#reset index bydeafult indexes ko lekar aajayegaa
df2.reset_index(inplace=True)

# %%
#dictionary
d={
    'name':['a','b','c'],
    'age':[10,20,30]
}

# %%
#conversion of dictionary to dataframe
pd.DataFrame(d)
# Out:
#   name  age
# 0    a   10
# 1    b   20
# 2    c   30

# %%
#code for dropping the na values
df2.dropna()
# Out:
#                                                   Name  Survived  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 6                              McCarthy, Mr. Timothy J         0       1
# 10                     Sandstrom, Miss. Marguerite Rut         1       3
# 11                            Bonnell, Miss. Elizabeth         1       1
# ..                                                 ...       ...     ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1       1
# 872                           Carlsson, Mr. Frans Olof         0       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 887                       Graham, Miss. Margaret Edith         1       1
# 889                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked  \
# ...

# %%
df2.dropna(inplace=True)

# %%
df2.fillna("omm")
# Out:
#                                                   Name  Survived  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 6                              McCarthy, Mr. Timothy J         0       1
# 10                     Sandstrom, Miss. Marguerite Rut         1       3
# 11                            Bonnell, Miss. Elizabeth         1       1
# ..                                                 ...       ...     ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1       1
# 872                           Carlsson, Mr. Frans Olof         0       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 887                       Graham, Miss. Margaret Edith         1       1
# 889                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked  \
# ...

# %%
#groupby operation survived ke andar 2 category hai 0 auur 1
g=df2.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#                                                        Name  Pclass  \
# Survived
# 0         McCarthy, Mr. Timothy JFortune, Mr. Charles Al...      73
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...     145
#
#                                                         Sex      Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalemalemalemalemalema...  2481.00     22
# 1         femalefemalefemalefemalemalemalefemalefemalefe...  4047.42     63
#
#           Parch                                             Ticket  \
# Survived
# 0            27  174631995011350936973348123W.E.P. 5734PC 17754...
# 1            60  PC 17599113803PP 9549113783248698113788PC 1757...
#
#                 Fare                                              Cabin  \
# Survived
# 0          3842.8957  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         10555.9961  C85C123G6C103D56A6D33F33C23 C25 C27D10 D12E101...
#
# ...

# %%
#agar mujhe average dekhna hai
g.mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7e482d906890>>

# %%
g.max()
# Out:
#                                Name  Pclass   Sex   Age  SibSp  Parch  \
# Survived
# 0         Widener, Mr. Harry Elkins       3  male  71.0      3      4
# 1          Young, Miss. Marie Grice       3  male  80.0      3      2
#
#              Ticket      Fare Cabin Embarked  new_col  new_col2
# Survived
# 0         WE/P 5735  263.0000     T        S        0       874
# 1         WE/P 5735  512.3292    G6        S        0       891

# %%
g.max()["Fare"]
# Out:
# Survived
# 0    263.0000
# 1    512.3292
# Name: Fare, dtype: float64

# %%
#covert the data rows to columns and columns to rows
g.max().transpose()
# Out:
# Survived                          0                         1
# Name      Widener, Mr. Harry Elkins  Young, Miss. Marie Grice
# Pclass                            3                         3
# Sex                            male                      male
# Age                            71.0                      80.0
# SibSp                             3                         3
# Parch                             4                         2
# Ticket                    WE/P 5735                 WE/P 5735
# Fare                          263.0                  512.3292
# Cabin                             T                        G6
# Embarked                          S                         S
# new_col                           0                         0
# new_col2                        874                       891

# %%
#lets select some subsets of the data
df5=df2[['Age','Fare','Survived']][0:5]

# %%
df6=df2[['Age','Fare','Survived']][5:10]

# %%
df5
# Out:
#      Age     Fare  Survived
# 1   38.0  71.2833         1
# 3   35.0  53.1000         1
# 6   54.0  51.8625         0
# 10   4.0  16.7000         1
# 11  58.0  26.5500         1

# %%
df6
# Out:
#      Age      Fare  Survived
# 21  34.0   13.0000         1
# 23  28.0   35.5000         1
# 27  19.0  263.0000         0
# 52  49.0   76.7292         1
# 54  65.0   61.9792         0

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7
# Out:
#      Age     Fare  Survived   Age      Fare  Survived
# 1   38.0  71.2833       1.0   NaN       NaN       NaN
# 3   35.0  53.1000       1.0   NaN       NaN       NaN
# 6   54.0  51.8625       0.0   NaN       NaN       NaN
# 10   4.0  16.7000       1.0   NaN       NaN       NaN
# 11  58.0  26.5500       1.0   NaN       NaN       NaN
# 21   NaN      NaN       NaN  34.0   13.0000       1.0
# 23   NaN      NaN       NaN  28.0   35.5000       1.0
# 27   NaN      NaN       NaN  19.0  263.0000       0.0
# 52   NaN      NaN       NaN  49.0   76.7292       1.0
# 54   NaN      NaN       NaN  65.0   61.9792       0.0

# %%
df7.fillna("omm")
# Out:
#      Age     Fare Survived   Age     Fare Survived
# 1   38.0  71.2833      1.0   omm      omm      omm
# 3   35.0     53.1      1.0   omm      omm      omm
# 6   54.0  51.8625      0.0   omm      omm      omm
# 10   4.0     16.7      1.0   omm      omm      omm
# 11  58.0    26.55      1.0   omm      omm      omm
# 21   omm      omm      omm  34.0     13.0      1.0
# 23   omm      omm      omm  28.0     35.5      1.0
# 27   omm      omm      omm  19.0    263.0      0.0
# 52   omm      omm      omm  49.0  76.7292      1.0
# 54   omm      omm      omm  65.0  61.9792      0.0

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,5,6,7],
              'key2':[2,3,4,5,6,7,8],
              'key3':[3,4,5,6,7,8,9]
              })

# %%
data2=pd.DataFrame({'key1':[1,2,3,4,5,6,7],
              'key4':[2,3,4,5,6,7,8],
              'key5':[3,4,5,6,7,8,9]
              })

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     2     3
# 1     2     3     4
# 2     3     4     5
# 3     4     5     6
# 4     5     6     7
# 5     6     7     8
# 6     7     8     9

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     2     3
# 1     2     3     4
# 2     3     4     5
# 3     4     5     6
# 4     5     6     7
# 5     6     7     8
# 6     7     8     9

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3     2     3
# 1     2     3     4     3     4
# 2     3     4     5     4     5
# 3     4     5     6     5     6
# 4     5     6     7     6     7
# 5     6     7     8     7     8
# 6     7     8     9     8     9

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3     2     3
# 1     2     3     4     3     4
# 2     3     4     5     4     5
# 3     4     5     6     5     6
# 4     5     6     7     6     7
# 5     6     7     8     7     8
# 6     7     8     9     8     9

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     2     3
# 1     2     3     4
# 2     3     4     5
# 3     4     5     6
# 4     5     6     7
# 5     6     7     8
# 6     7     8     9

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3     2     3
# 1     2     3     4     3     4
# 2     3     4     5     4     5
# 3     4     5     6     5     6
# 4     5     6     7     6     7
# 5     6     7     8     7     8
# 6     7     8     9     8     9

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3     2     3
# 1     2     3     4     3     4
# 2     3     4     5     4     5
# 3     4     5     6     5     6
# 4     5     6     7     6     7
# 5     6     7     8     7     8
# 6     7     8     9     8     9

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     2     3     2     3
# 1     2     3     4     3     4
# 2     3     4     5     4     5
# 3     4     5     6     5     6
# 4     5     6     7     6     7
# 5     6     7     8     7     8
# 6     7     8     9     8     9

# %%
data={"a":[1,2,3,4,5],
      "b":[4,5,6,7,8],
      "c":["sudh","krish","sudh","krish","omm"]}

# %%
pd.DataFrame(data)
# Out:
#    a  b      c
# 0  1  4   sudh
# 1  2  5  krish
# 2  3  6   sudh
# 3  4  7  krish
# 4  5  8    omm
